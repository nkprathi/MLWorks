# %%
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans  

X, y = make_blobs(n_samples=5000, centers=5, random_state=42)

X
# Out:
# array([[-2.57187672,  9.96942845],
#        [ 0.0177348 ,  8.48341736],
#        [ 1.44408814,  4.45659254],
#        ...,
#        [ 3.82450321,  0.90693475],
#        [ 7.06659532,  2.40612951],
#        [-7.72164648,  7.55561755]], shape=(5000, 2))

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
import matplotlib.pyplot as plt

plt.scatter(X_scaled[:, 0], X_scaled[:, 1])

# %%
kmeans = KMeans(n_clusters=5)

kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=5)

# %%
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=kmeans.labels_, cmap='viridis')

# %%
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y, cmap='viridis')

# %%
from sklearn.datasets import make_moons

X, _ = make_moons(n_samples=500, noise=0.02, random_state=42)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1])

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X_scaled)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=kmeans.labels_, cmap='viridis')

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.2)
dbscan.fit(X_scaled)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=dbscan.labels_, cmap='viridis')
